# %%
# %run prediction_model.py
# Out:
# Dataset Loaded
# Rows: 4238
# Total Matchups Created: 22176
# Training rows: 20160
# Testing rows: 2016
# Model trained
#
# Model Accuracy: 0.998015873015873
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99       133
#            1       1.00      1.00      1.00      1883
#
#     accuracy                           1.00      2016
#    macro avg       0.99      1.00      0.99      2016
# weighted avg       1.00      1.00      1.00      2016
#
#
# Sample Game Predictions:
#        YEAR  ADJOE_diff  ADJDE_diff  BARTHAG_diff  TOR_diff  ORB_diff  \
# 20160  2024        -7.9        -8.1        0.0073      -1.2       0.4
# 20161  2024        -7.0        -9.2        0.0141      -2.8      -0.5
# 20162  2024         2.4        -7.7        0.0480      -0.7       4.1
# 20163  2024         5.6        -1.0        0.0202      -2.0       5.3
# 20164  2024        -2.3        -8.1        0.0259      -2.4       0.6
# ...

# %%
# %run march_madness_model.py
# Out:
# Accuracy: 0.9005524861878453
#
# Top Teams:
#              TEAM  TEAM_STRENGTH
# 3877  Connecticut       0.989730
# 3876      Houston       0.987821
# 3878       Purdue       0.983508
# 3888       Auburn       0.963671
# 3881      Arizona       0.958664
# 3880     Iowa St.       0.939312
# 3885     Illinois       0.919417
# 3884    Creighton       0.906808
# 3883    Marquette       0.906386
# 3889         Duke       0.905546
#
# ROUND OF 16
# Connecticut vs Duke → Connecticut
# Houston vs Kansas → Houston
# Purdue vs Arizona → Purdue
# Tennessee vs Baylor → Tennessee
# Gonzaga vs Alabama → Alabama
# Marquette vs Creighton → Creighton
# Illinois vs Auburn → Auburn
# Texas vs Kentucky → Kentucky
#
# ELITE 8
# Connecticut vs Houston → Connecticut
# Purdue vs Tennessee → Purdue
# Alabama vs Creighton → Creighton
# Auburn vs Kentucky → Auburn
#
# FINAL FOUR
# Connecticut vs Purdue → Connecticut
# Creighton vs Auburn → Auburn
#
# CHAMPIONSHIP
# Connecticut vs Auburn → Connecticut
#
# ...
